# %% [markdown]
# <a href="https://colab.research.google.com/github/khusnana/ML-capstone/blob/master/Bismillah_Recom.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import

import numpy as np
import pandas as pd
import os
import matplotlib.pyplot as plt
import seaborn as sns
from ast import literal_eval

# %matplotlib inline

# %%
veg_meat = ["#454d66", "#b7e778", "#1fab89"]
sns.set_palette(veg_meat)

# %%
for dirname, _, filenames in os.walk('D:/dataset_Recipe'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
recipes = pd.read_csv('D:/Dataset_Recipe/RAW_recipes.csv')
interactions = pd.read_csv('D:/Dataset_Recipe/RAW_interactions.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-54acf28337d8> in <cell line: 1>()
# ----> 1 recipes = pd.read_csv('D:/Dataset_Recipe/RAW_recipes.csv')
#       2 interactions = pd.read_csv('D:/Dataset_Recipe/RAW_interactions.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     948     kwds.update(kwds_defaults)
#     949
# --> 950     return _read(filepath_or_buffer, kwds)
#     951
#     952
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     603
#     604     # Create the parser.
# --> 605     parser = TextFileReader(filepath_or_buffer, **kwds)
#     606
#     607     if chunksize or iterator:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1440
#    1441         self.handles: IOHandles | None = None
# -> 1442         self._engine = self._make_engine(f, self.engine)
#    1443
#    1444     def close(self) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1733                 if "b" not in mode:
#    1734                     mode += "b"
# -> 1735             self.handles = get_handle(
#    1736                 f,
#    1737                 mode,
#
# /usr/local/lib/python3.10/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854         if ioargs.encoding and "b" not in ioargs.mode:
#     855             # Encoding
# --> 856             handle = open(
#     857                 handle,
#     858                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'D:/Dataset_Recipe/RAW_recipes.csv'

# %%
recipes.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa9403ecc768> in <cell line: 1>()
# ----> 1 recipes.head()
#
# NameError: name 'recipes' is not defined

# %%
print(recipes.info())
recipes.describe()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-8883d38c9b33> in <cell line: 1>()
# ----> 1 print(recipes.info())
#       2 recipes.describe()
#
# NameError: name 'recipes' is not defined

# %%
recipes.isnull().sum().sum()
# Out:
# 4980

# %%
interactions.isnull().sum().sum()
# Out:
# 169

# %%
df = pd.DataFrame(recipes)
columns_list = list(df.columns)
print(columns_list)
# Out:
# ['name', 'id', 'minutes', 'contributor_id', 'submitted', 'tags', 'nutrition', 'n_steps', 'steps', 'description', 'ingredients', 'n_ingredients']

# %%
recipes.shape, interactions.shape
# Out:
# ((231637, 12), (1132367, 5))

# %%
a = recipes.sample(50000)
b = interactions.sample(50000)

# %%
data = pd.merge(b,a, right_on = 'id', left_on='recipe_id')

# %%
data.shape
# Out:
# (10946, 17)

# %%
data.head(5)
# Out:
#       user_id  recipe_id        date  rating  \
# 0       68960      17210  2006-11-12       5
# 1  2000725152      17210  2015-12-02       2
# 2       69718      17210  2008-01-04       4
# 3  2002194196      17210  2018-06-22       5
# 4       49126      17210  2006-01-21       5
#
#                                               review  \
# 0  I thought I'd reviewed this!  This is fabulous...
# 1  Caution: BLAND recipe. Triple the herbs. Inste...
# 2  I modified this a bit as follows:  no rosemary...
# 3  I browned the meat in Bacon fat, added black p...
# 4  Very very tasty dish! Halved the recipe and co...
#
#                          name     id  minutes  contributor_id   submitted  \
# 0  crock pot rustic lamb stew  17210      610           21752  2002-01-14
# 1  crock pot rustic lamb stew  17210      610           21752  2002-01-14
# 2  crock pot rustic lamb stew  17210      610           21752  2002-01-14
# 3  crock pot rustic lamb stew  17210      610           21752  2002-01-14
# 4  crock pot rustic lamb stew  17210      610           21752  2002-01-14
#
#                                                 tags  \
# 0  ['weeknight', 'time-to-make', 'course', 'main-...
# 1  ['weeknight', 'time-to-make', 'course', 'main-...
# 2  ['weeknight', 'time-to-make', 'course', 'main-...
# 3  ['weeknight', 'time-to-make', 'course', 'main-...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                      nutrition  n_steps  \
# 0  [387.0, 17.0, 21.0, 31.0, 78.0, 17.0, 10.0]       11
# 1  [387.0, 17.0, 21.0, 31.0, 78.0, 17.0, 10.0]       11
# 2  [387.0, 17.0, 21.0, 31.0, 78.0, 17.0, 10.0]       11
# 3  [387.0, 17.0, 21.0, 31.0, 78.0, 17.0, 10.0]       11
# 4  [387.0, 17.0, 21.0, 31.0, 78.0, 17.0, 10.0]       11
#
#                                                steps  \
# 0  ['sprinkle lamb with 1 / 2 t salt and the pepp...
# 1  ['sprinkle lamb with 1 / 2 t salt and the pepp...
# 2  ['sprinkle lamb with 1 / 2 t salt and the pepp...
# 3  ['sprinkle lamb with 1 / 2 t salt and the pepp...
# 4  ['sprinkle lamb with 1 / 2 t salt and the pepp...
#
#                                          description  \
# 0  the original recipe here called for rutabagas,...
# 1  the original recipe here called for rutabagas,...
# 2  the original recipe here called for rutabagas,...
# 3  the original recipe here called for rutabagas,...
# 4  the original recipe here called for rutabagas,...
#
#                                          ingredients  n_ingredients
# 0  ['lean lamb stew meat', 'salt', 'pepper', 'all...             12
# 1  ['lean lamb stew meat', 'salt', 'pepper', 'all...             12
# 2  ['lean lamb stew meat', 'salt', 'pepper', 'all...             12
# 3  ['lean lamb stew meat', 'salt', 'pepper', 'all...             12
# 4  ['lean lamb stew meat', 'salt', 'pepper', 'all...             12

# %%
data.drop(["user_id","submitted","contributor_id","id"],axis=1,inplace=True)

# %%
data.describe()
# Out:
#            recipe_id        rating        minutes       n_steps  n_ingredients
# count   10946.000000  10946.000000   10946.000000  10946.000000   10946.000000
# mean   158914.966289      4.418144     129.327060      9.784944       9.032889
# std    129159.522672      1.264736    2197.704975      5.772699       3.735085
# min       120.000000      0.000000       0.000000      1.000000       1.000000
# 25%     54253.250000      4.000000      23.000000      6.000000       6.000000
# 50%    118887.000000      5.000000      40.000000      9.000000       9.000000
# 75%    236084.500000      5.000000      70.000000     12.000000      11.000000
# max    536568.000000      5.000000  167040.000000     88.000000      31.000000

# %%
data[['calories','total fat','sugar','sodium','protein','saturated fat','carbohydrates']] = data.nutrition.str.split(",",expand=True) 
data['calories'] = data['calories'].apply(lambda x: x.replace("[" ,""))
data['carbohydrates'] = data['carbohydrates'].apply(lambda x: x.replace("]" ,""))
data[['calories','total fat','sugar','sodium','protein','saturated fat','carbohydrates']] =  data[['calories','total fat','sugar','sodium','protein','saturated fat','carbohydrates']].astype(float)

# %%
data.isnull().sum()
# Out:
# recipe_id        0
# date             0
# rating           0
# review           0
# name             0
# minutes          0
# tags             0
# nutrition        0
# n_steps          0
# steps            0
# description      0
# ingredients      0
# n_ingredients    0
# calories         0
# total fat        0
# sugar            0
# sodium           0
# protein          0
# saturated fat    0
# carbohydrates    0
# dtype: int64

# %%
df = pd.DataFrame(data)
df_cleaned = data.dropna(inplace=False)
df_cleaned.to_csv('D:\Dataset_Recipe\data_cleaned1.csv', index=False)

# %%
data.columns
# Out:
# Index(['recipe_id', 'date', 'rating', 'review', 'name', 'minutes', 'tags',
#        'nutrition', 'n_steps', 'steps', 'description', 'ingredients',
#        'n_ingredients', 'calories', 'total fat', 'sugar', 'sodium', 'protein',
#        'saturated fat', 'carbohydrates'],
#       dtype='object')

# %%
nonveg = ["egg", "egg whites"]
def ingredient_check(data):
    veg = 0
    for b in literal_eval(data):
        if b in nonveg:
            veg = 1
        else :
            veg = 0
    return veg
data["non veg"] = data ["ingredients"].apply(ingredient_check)

# %%
data["non veg"].value_counts()
# Out:
# 0    10597
# 1       75
# Name: non veg, dtype: int64

# %%
hv.Distribution(df_p2.rating).opts(opts.Distribution(title="Distribution of Rating",tools=['hover'],show_grid=True)) + \
hv.BoxWhisker(df_p2.rating).opts(opts.BoxWhisker(title="Rating BoxPlot",tools=['hover'],show_grid=True))
# Out:
# :Layout
#    .Distribution.I :Distribution   [rating]   (Density)
#    .BoxWhisker.I   :BoxWhisker   (y)

# %%
df_p2[["calories","protein","fat","sodium"]].mean()
# Out:
# calories    6350.682993
# protein      100.324571
# fat          346.986826
# sodium      6252.742310
# dtype: float64

# %%
g1 = hv.BoxWhisker(df_p2.calories).opts(opts.BoxWhisker(title="calories"))
g2 = hv.BoxWhisker(df_p2.protein).opts(opts.BoxWhisker(title="protein"))
g3 = hv.BoxWhisker(df_p2.fat).opts(opts.BoxWhisker(title="fat"))
g4 = hv.BoxWhisker(df_p2.sodium).opts(opts.BoxWhisker(title="sodium"))

(g1+g2+g3+g4).opts(opts.BoxWhisker(width=300, ylabel="value",tools=['hover'],show_grid=True)).opts(shared_axes=False).cols(2)
# Out:
# :Layout
#    .BoxWhisker.I   :BoxWhisker   (y)
#    .BoxWhisker.II  :BoxWhisker   (y)
#    .BoxWhisker.III :BoxWhisker   (y)
#    .BoxWhisker.IV  :BoxWhisker   (y)

# %%
tmp = df_p2.drop(["title","rating","calories","protein","fat","sodium","len_directions","len_ingredients"], axis=1)
p = pd.DataFrame()
for c in tmp.columns:
    _tmp = tmp[c].value_counts(normalize=True) * 100
    p = pd.concat([p,_tmp], axis=1)
t = pd.melt(p.reset_index(), ['index'])

g1 = hv.Bars(t.query("variable in ['bread','rice','meat','egg','drink','drinks','alcoholic','vegetable']"), ['variable','index'], 'value').opts(title='Ingredients')
g2 = hv.Bars(t.query("variable in ['spring','summer','fall','winter']"), ['variable','index'], 'value').opts(title='Season')
g3 = hv.Bars(t.query("variable in ['breakfast','lunch','dinner']"), ['variable','index'], 'value').opts(title='Eat Timing')
g4 = hv.Bars(t.query("variable in ['22-minute meals','advance prep required','quick & easy','quick and healthy']"), ['variable','index'], 'value')\
    .opts(title='Cooking Categories')
g5 = hv.Bars(t.query("variable in ['healthy','fat free','high fiber','low cal','low carb','low cholesterol','low fat','low sodium','low sugar','low/no sugar']"), \
             ['variable','index'], 'value').opts(title='Recipe Categories')

(g1+g2+g3+g4+g5)\
    .opts(opts.Bars(width=250, height=400,invert_axes=True,stacked=True,legend_position='bottom',tools=['hover'],show_grid=True,xlabel="",ylabel="",fontsize={'title':10}))\
    .opts(shared_axes=False).cols(3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tmp = df_p2.drop(["title","rating","calories","protein","fat","sodium","len_directions","len_ingredients"], axis=1)
#       2 p = pd.DataFrame()
#       3 for c in tmp.columns:
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['len_directions', 'len_ingredients'] not found in axis"

# %%
import pandas as pd
from wordcloud import WordCloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13056\3591433716.py in <module>
#       1 import pandas as pd
# ----> 2 from wordcloud import WordCloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
pip install wordcloud
# Out:
# Collecting wordcloud
#   Downloading wordcloud-1.9.2-cp37-cp37m-win_amd64.whl (152 kB)
#      ------------------------------------ 152.5/152.5 kB 146.8 kB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.6.1 in c:\users\user\appdata\roaming\python\python37\site-packages (from wordcloud) (1.21.6)
# Requirement already satisfied: pillow in c:\users\user\appdata\roaming\python\python37\site-packages (from wordcloud) (9.5.0)
# Requirement already satisfied: matplotlib in c:\users\user\appdata\roaming\python\python37\site-packages (from wordcloud) (3.5.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\user\appdata\roaming\python\python37\site-packages (from matplotlib->wordcloud) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\user\appdata\roaming\python\python37\site-packages (from matplotlib->wordcloud) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\user\appdata\roaming\python\python37\site-packages (from matplotlib->wordcloud) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\user\appdata\roaming\python\python37\site-packages (from matplotlib->wordcloud) (20.9)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\user\appdata\roaming\python\python37\site-packages (from matplotlib->wordcloud) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\user\appdata\roaming\python\python37\site-packages (from matplotlib->wordcloud) (2.8.2)
# Requirement already satisfied: typing-extensions in c:\users\user\appdata\roaming\python\python37\site-packages (from kiwisolver>=1.0.1->matplotlib->wordcloud) (4.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\user\appdata\roaming\python\python37\site-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.16.0)
# Installing collected packages: wordcloud
# Successfully installed wordcloud-1.9.2
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\roaming\python\python37\site-packages)

# %%
pip install --upgrade protobuf
# Out:
# Requirement already satisfied: protobuf in c:\users\user\appdata\roaming\python\python37\site-packages (4.23.1)Note: you may need to restart the kernel to use updated packages.
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\roaming\python\python37\site-packages)
# WARNING: Ignoring invalid distribution -rotobuf (c:\users\user\appdata\roaming\python\python37\site-packages)
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-api-core 2.11.0 requires google-auth<3.0dev,>=2.14.1, but you have google-auth 1.35.0 which is incompatible.
# tensorflow-intel 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.23.2 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorboard<2.12,>=2.11, but you have tensorboard 2.2.2 which is incompatible.
# tensorflow-intel 2.11.0 requires tensorflow-estimator<2.12,>=2.11.0, but you have tensorflow-estimator 2.2.0 which is incompatible.
# tensorflow-serving-api 2.11.0 requires protobuf<3.20,>=3.9.2, but you have protobuf 4.23.2 which is incompatible.
# tensorflow-serving-api 2.11.0 requires tensorflow<3,>=2.11.0, but you have tensorflow 2.2.0 which is incompatible.
# tensorflowjs 3.19.0 requires protobuf==3.20.0, but you have protobuf 4.23.2 which is incompatible.
# Collecting protobuf
#   Downloading protobuf-4.23.2-cp37-cp37m-win_amd64.whl (422 kB)
#      ------------------------------------- 422.0/422.0 kB 47.0 kB/s eta 0:00:00
# Installing collected packages: protobuf
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 4.23.1
#     Uninstalling protobuf-4.23.1:
#       Successfully uninstalled protobuf-4.23.1
# Successfully installed protobuf-4.23.2

# %%
import pandas as pd
from wordcloud import WordCloud

# %%
def minimal_wordcloud(df, column):
    text = str(df[column].values)
    wordcloud = WordCloud().generate(text)
    image = wordcloud.to_image()
    return image
